# %%
import evaluate2d as e2
import query_engine as qe

# %% [markdown]
# #  Dataset 6 Count

# %% [markdown]
# ## 0.5% query range

# %%
qe6 = e2.Query_Engine_2d(6,logger_file="../results/6_COUNT_0.5.txt")

# %%
exact_results6_count_0_5, approx_results6_count_0_5, exact_times6_count_0_5, approx_times6_count_0_5 = qe6.mass_query_count(number=1500,percent=0.5)
# Out:
# INFO - start query No.1 out of 1500
# INFO - Approximate count: 4.5623.
# INFO - Time spent for approximate COUNT: 0.9324s.
# INFO - 4
# INFO - SELECT COUNT(y) FROM table6 WHERE  x BETWEEN 9.69001510568709 AND 9.99112080568709
# INFO - Time spent for HIVE query: 17.1644s.
# INFO - 9
# INFO - start query No.2 out of 1500
# INFO - Approximate count: 3041.8616.
# INFO - Time spent for approximate COUNT: 1.1247s.
# INFO - 3041
# INFO - SELECT COUNT(y) FROM table6 WHERE  x BETWEEN 52.631872862820266 AND 52.93297856282026
# INFO - Time spent for HIVE query: 19.2837s.
# INFO - 2750
# INFO - start query No.3 out of 1500
# INFO - Approximate count: 10204.6692.
# INFO - Time spent for approximate COUNT: 1.2173s.
# INFO - 10204
# INFO - SELECT COUNT(y) FROM table6 WHERE  x BETWEEN 47.593825407837336 AND 47.89493110783733
# INFO - Time spent for HIVE query: 20.9284s.
# INFO - 10452
# INFO - start query No.4 out of 1500
# INFO - Approximate count: 45.8201.
# ...

# %%
qe6.relative_error(exact_results6_count_0_5, approx_results6_count_0_5)
qe6.time_ratio(exact_times6_count_0_5, approx_times6_count_0_5)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-10-a0dd28864595> in <module>()
# ----> 1 qe6.relative_error(exact_results6_count_0_5, approx_results6_count_0_5)
#       2 qe6.time_ratio(exact_times6_count_0_5, approx_times6_count_0_5)
#
# /disk/workspace/CRegressionRDBM/creg/evaluate2d.pyc in relative_error(self, exact_results, approx_results)
#     154     def relative_error(self,exact_results, approx_results):
#     155         # abs_errors = [abs(i - j) for i, j in zip(exact_results,approx_results) ]
# --> 156         rel_errors = [abs(i - j)*1.0/i for i, j in zip(exact_results,approx_results) ]
#     157         # abs_time_reduction = [(j - i) for i, j in zip(exact_times, approx_times) ]
#     158         result = sum(rel_errors)/len(rel_errors)
#
# ZeroDivisionError: float division by zero

# %% [markdown]
# ## 1% query range

# %%
qe6.logger.set_logging(file_name="../results/6_COUNT_1.txt")

# %%
exact_results6_count_1, approx_results6_count_1, exact_times6_count_1, approx_times6_count_1 = qe6.mass_query_count(number=1500,percent=1)
# Out:
# INFO - start query No.1 out of 1500
# INFO - Approximate count: 9.1206.
# INFO - Time spent for approximate COUNT: 0.7760s.
# INFO - 9
# INFO - SELECT COUNT(y) FROM table6 WHERE  x BETWEEN 9.53946225568709 AND 10.141673655687091
# INFO - Time spent for HIVE query: 19.3856s.
# INFO - 12
# INFO - start query No.2 out of 1500
# INFO - Approximate count: 6092.3504.
# INFO - Time spent for approximate COUNT: 0.8652s.
# INFO - 6092
# INFO - SELECT COUNT(y) FROM table6 WHERE  x BETWEEN 52.48132001282026 AND 53.083531412820264
# INFO - Time spent for HIVE query: 19.4293s.
# INFO - 5658
# INFO - start query No.3 out of 1500
# INFO - Approximate count: 20402.4061.
# INFO - Time spent for approximate COUNT: 0.9646s.
# INFO - 20402
# INFO - SELECT COUNT(y) FROM table6 WHERE  x BETWEEN 47.44327255783733 AND 48.045483957837334
# INFO - Time spent for HIVE query: 19.0274s.
# INFO - 20870
# INFO - start query No.4 out of 1500
# INFO - Approximate count: 91.7726.
# ...

# %%
qe6.relative_error(exact_results6_count_1, approx_results6_count_1)
qe6.time_ratio(exact_times6_count_1, approx_times6_count_1)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-13-f3b07c2b9ffe> in <module>()
# ----> 1 qe6.relative_error(exact_results6_count_1, approx_results6_count_1)
#       2 qe6.time_ratio(exact_times6_count_1, approx_times6_count_1)
#
# /disk/workspace/CRegressionRDBM/creg/evaluate2d.pyc in relative_error(self, exact_results, approx_results)
#     154     def relative_error(self,exact_results, approx_results):
#     155         # abs_errors = [abs(i - j) for i, j in zip(exact_results,approx_results) ]
# --> 156         rel_errors = [abs(i - j)*1.0/i for i, j in zip(exact_results,approx_results) ]
#     157         # abs_time_reduction = [(j - i) for i, j in zip(exact_times, approx_times) ]
#     158         result = sum(rel_errors)/len(rel_errors)
#
# ZeroDivisionError: float division by zero

# %% [markdown]
# ## 5% query range

# %%
qe6.logger.set_logging(file_name="../results/6_COUNT_5.txt")

# %%
exact_results6_count_5, approx_results6_count_5, exact_times6_count_5, approx_times6_count_5 = qe6.mass_query_count(number=1500,percent=5)
# Out:
# INFO - start query No.1 out of 1500
# INFO - Approximate count: 45.5831.
# INFO - Time spent for approximate COUNT: 0.7287s.
# INFO - 45
# INFO - SELECT COUNT(y) FROM table6 WHERE  x BETWEEN 8.33503945568709 AND 11.346096455687091
# INFO - Time spent for HIVE query: 18.9856s.
# INFO - 44
# INFO - start query No.2 out of 1500
# INFO - Approximate count: 31743.1540.
# INFO - Time spent for approximate COUNT: 0.9005s.
# INFO - 31743
# INFO - SELECT COUNT(y) FROM table6 WHERE  x BETWEEN 51.276897212820266 AND 54.28795421282026
# INFO - Time spent for HIVE query: 18.9964s.
# INFO - 29966
# INFO - start query No.3 out of 1500
# INFO - Approximate count: 100892.6748.
# INFO - Time spent for approximate COUNT: 0.9286s.
# INFO - 100892
# INFO - SELECT COUNT(y) FROM table6 WHERE  x BETWEEN 46.238849757837336 AND 49.24990675783733
# INFO - Time spent for HIVE query: 19.0194s.
# INFO - 102329
# INFO - start query No.4 out of 1500
# INFO - Approximate count: 478.4515.
# ...

# %%
qe6.relative_error(exact_results6_count_5, approx_results6_count_5)
qe6.time_ratio(exact_times6_count_5, approx_times6_count_5)
# Out:
# INFO - Relative error is : 0.114615929017
# INFO - Time ratio is : 0.0392605310825
# 0.03926053108250397
