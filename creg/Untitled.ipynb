# %%
import core 
import tools
import data_loader

# %%
data=data_loader.load5d(7)
cr = core.CRegression(base_models=[  #tools.app_linear,tools.app_poly,tools.app_decision_tree,\
        tools.app_boosting,tools.app_xgboost],\
        b_show_plot=False)
cr.run(data)
# Out:
# DEBUG - Sucessfully deployed sklearn_gradient_tree_boosting
# DEBUG - Sucessfully deployed sklearn_gradient_tree_boosting
# DEBUG - Time cost to train the model is : 10.99776 s.
# DEBUG - Time cost to train the model is : 10.99776 s.
# DEBUG - Sucessfully deployed xgboost
# DEBUG - Sucessfully deployed xgboost
# DEBUG - Time cost to train the model is : 19.34941 s.
# DEBUG - Time cost to train the model is : 19.34941 s.
# INFO - Start querying to sklearn_gradient_tree_boosting.
# INFO - Start querying to sklearn_gradient_tree_boosting.
# DEBUG - Finish 1392835 queries, average latency is 0.054113 ms.
# DEBUG - Finish 1392835 queries, average latency is 0.054113 ms.
# INFO - Total time spent: 75.3707 s.
# INFO - Total time spent: 75.3707 s.
# INFO - --------------------------------------------------------------------------------------------
# INFO - --------------------------------------------------------------------------------------------
# INFO - Start querying to xgboost.
# ...

# %%
cr.boxplot_with_barplot(proportion_to_show=0.50, bar_width=0.05,cumulative=False,\
        b_show_rest=False,y_limit=[0,10])
cr.boxplot_with_barplot(proportion_to_show=0.50, bar_width=0.05,cumulative=True,\
        b_show_rest=False,y_limit=[0,1.1])
# Out:
# [1314.6091455872631, 1298.5045917530613, 1598.7466621918547]
