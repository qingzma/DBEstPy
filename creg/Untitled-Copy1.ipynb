# %%
import core 
import tools
import data_loader

# %%
data=data_loader.load5d(8)
cr = core.CRegression(base_models=[  #tools.app_linear,tools.app_poly,tools.app_decision_tree,\
        tools.app_boosting,tools.app_xgboost],\
        b_show_plot=False)
cr.run(data)
# Out:
# DEBUG - Sucessfully deployed sklearn_gradient_tree_boosting
# DEBUG - Time cost to train the model is : 6.72672 s.
# DEBUG - Sucessfully deployed xgboost
# DEBUG - Time cost to train the model is : 10.92734 s.
# INFO - Start querying to sklearn_gradient_tree_boosting.
# DEBUG - Finish 683093 queries, average latency is 0.053892 ms.
# INFO - Total time spent: 36.8135 s.
# INFO - --------------------------------------------------------------------------------------------
# INFO - Start querying to xgboost.
# DEBUG - Finish 683093 queries, average latency is 0.198829 ms.
# INFO - Total time spent: 135.8189 s.
# INFO - --------------------------------------------------------------------------------------------
# DEBUG - Queries are classified into 2 categories:
# DEBUG - Counts are: [229101 453992].
# DEBUG - Total time to train xgboost classifier is: 12.3613 s.
# INFO - Start querying to sklearn_gradient_tree_boosting.
# DEBUG - Finish 683093 queries, average latency is 0.053519 ms.
# ...

# %%
cr.boxplot_with_barplot(proportion_to_show=0.001, bar_width=0.0001,cumulative=False,\
        b_show_rest=False,y_limit=None)
cr.boxplot_with_barplot(proportion_to_show=0.001, bar_width=0.0001,cumulative=True,\
        b_show_rest=False,y_limit=[0,1.1])
# Out:
# [22.383618974197375, 21.720365756318948, 22.69400472923498]
